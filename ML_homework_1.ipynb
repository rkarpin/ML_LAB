# %% [markdown]
# <a href="https://colab.research.google.com/github/rkarpin/ML_LAB/blob/main/ML_homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import PCA

# %%
data = pd.read_csv('https://raw.githubusercontent.com/SzymonNowakowski/Machine-Learning-2024/refs/heads/master/PCA_three_clusters_data.csv')

# %%
data
# Out:
#             x         y          z  class
# 0    0.647689 -0.138264   3.512299      0
# 1   -0.234137 -0.234153  10.769447      0
# 2   -0.469474  0.767435  11.166721      0
# 3   -0.465730 -0.463418   3.836479      0
# 4   -1.724918 -1.913280   1.710932      0
# ..        ...       ...        ...    ...
# 295  4.640708  0.583928  13.058193      2
# 296  5.820482  1.108704   4.176560      2
# 297  6.169296  1.066675   3.586969      2
# 298  4.832882  0.648710   9.773340      2
# 299  4.183064  1.206509   1.037422      2
#
# [300 rows x 4 columns]

# %%
x = data["x"]
y = data["y"]
z = data["z"]
classes = data["class"]

# %%
plt.scatter(x,y,c=classes,cmap='brg', alpha =0.7)
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
plt.scatter(y,z,c=classes,cmap='brg', alpha =0.7)
plt.xlabel("y")
plt.ylabel("z")
plt.grid(True)
plt.show()
plt.scatter(x,z,c=classes,cmap='brg', alpha =0.7)
plt.xlabel("x")
plt.ylabel("z")
plt.grid(True)
plt.show()

# %%
df = data[['x','y','z']]
df=(df-df.mean())/df.std()
pca = PCA(n_components = 3)
df = pca.fit_transform(df)
df=df.T

# %%
plt.scatter(df[0],df[1],c=classes,cmap='brg', alpha =0.7)
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.grid(True)
plt.show()

# %% [markdown]
# # Pytanie 1
# PCA pogorszyło separację klastrów. Stało się tak, bo kierunki o największej wariancji to niekoniecznie kierunki najlepiej rozdzielające klastry. W tym przypadku kierunek rozdzielający klastry miał małą wariancję.
#
# # Pytanie 2
#
# Standaryzacja jest ważna w PCA, bo zapobiega dominacji cech o dużej skali. Gdyby np. jedna cecha miała wartości w kilometrach, a druga w milimetrach, to PCA faworyzowałoby pierwszą cechę, bo będzia miała większą wariancję - nawet gdyby to druga cecha była bardziej istotna.
